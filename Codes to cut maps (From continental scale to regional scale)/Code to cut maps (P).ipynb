# %%
import geopandas as gpd
from shapely.geometry import polygon
import matplotlib.pyplot as plt

# %%
# Catalonia map for fuel 1

# %%
fuel1 = gpd.read_file("/home/coca/Maps_TFM/Polygon/Europe/fuelCategory1.geojson")

# %%
fuel1['geometry'].crs
# Out:
# <Projected CRS: EPSG:3035>
# Name: ETRS89-extended / LAEA Europe
# Axis Info [cartesian]:
# - Y[north]: Northing (metre)
# - X[east]: Easting (metre)
# Area of Use:
# - name: Europe - LCC & LAEA
# - bounds: (-35.58, 24.6, 44.83, 84.17)
# Coordinate Operation:
# - name: Europe Equal Area 2001
# - method: Lambert Azimuthal Equal Area
# Datum: European Terrestrial Reference System 1989
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
fuel1_proj=fuel1.to_crs(25831)

# %%
fuel1_proj['geometry'].crs
# Out:
# <Projected CRS: EPSG:25831>
# Name: ETRS89 / UTM zone 31N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Europe - 0°E to 6°E and ETRS89 by country
# - bounds: (0.0, 37.0, 6.01, 82.41)
# Coordinate Operation:
# - name: UTM zone 31N
# - method: Transverse Mercator
# Datum: European Terrestrial Reference System 1989
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
cat_shape = gpd.read_file("/home/coca/Maps_TFM/Maps_Cat_ICGC/divisions-administratives-v2r1-catalunya-1000000-20220801.shp")

# %%
cat_shape['geometry'].crs
# Out:
# <Projected CRS: EPSG:25831>
# Name: ETRS89 / UTM zone 31N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Europe - 0°E to 6°E and ETRS89 by country
# - bounds: (0.0, 37.0, 6.01, 82.41)
# Coordinate Operation:
# - name: UTM zone 31N
# - method: Transverse Mercator
# Datum: European Terrestrial Reference System 1989
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
CatFuel1 = fuel1_proj.overlay(cat_shape, how ='intersection')

# %%
CatFuel1.plot()
# Out:
# <AxesSubplot: >

# %%
CatFuel1.to_file("/home/coca/Maps_TFM/Polygon/Catalonia/CatFuel1.geojson",driver='GeoJSON')

# %%
# Catalonia map for fuel 2

# %%
fuel2 = gpd.read_file("/home/coca/Maps_TFM/Polygon/Europe/fuelCategory2.geojson")
fuel2_proj=fuel2.to_crs(25831)
cat_shape = gpd.read_file("/home/coca/Maps_TFM/Maps_Cat_ICGC/divisions-administratives-v2r1-catalunya-1000000-20220801.shp")
CatFuel2 = fuel2_proj.overlay(cat_shape, how ='intersection')
CatFuel2.to_file("/home/coca/Maps_TFM/Polygon/Catalonia/CatFuel2.geojson",driver='GeoJSON')

# %%
# Catalonia map for fuel 3

# %%
fuel3 = gpd.read_file("/home/coca/Maps_TFM/Polygon/Europe/fuelCategory3.geojson")
fuel3_proj=fuel3.to_crs(25831)
cat_shape = gpd.read_file("/home/coca/Maps_TFM/Maps_Cat_ICGC/divisions-administratives-v2r1-catalunya-1000000-20220801.shp")
CatFuel3 = fuel3_proj.overlay(cat_shape, how ='intersection')
CatFuel3.to_file("/home/coca/Maps_TFM/Polygon/Catalonia/CatFuel3.geojson",driver='GeoJSON')

# %%
# Catalonia map for fuel 4

# %%
fuel4 = gpd.read_file("/home/coca/Maps_TFM/Polygon/Europe/fuelCategory4.geojson")
fuel4_proj=fuel4.to_crs(25831)
cat_shape = gpd.read_file("/home/coca/Maps_TFM/Maps_Cat_ICGC/divisions-administratives-v2r1-catalunya-1000000-20220801.shp")
CatFuel4 = fuel4_proj.overlay(cat_shape, how ='intersection')
CatFuel4.to_file("/home/coca/Maps_TFM/Polygon/Catalonia/CatFuel4.geojson",driver='GeoJSON')

# %%
# Catalonia map for fuel 5

# %%
fuel5 = gpd.read_file("/home/coca/Maps_TFM/Polygon/Europe/fuelCategory5.geojson")
fuel5_proj=fuel5.to_crs(25831)
cat_shape = gpd.read_file("/home/coca/Maps_TFM/Maps_Cat_ICGC/divisions-administratives-v2r1-catalunya-1000000-20220801.shp")
CatFuel5 = fuel5_proj.overlay(cat_shape, how ='intersection')
CatFuel5.to_file("/home/coca/Maps_TFM/Polygon/Catalonia/CatFuel5.geojson",driver='GeoJSON')
