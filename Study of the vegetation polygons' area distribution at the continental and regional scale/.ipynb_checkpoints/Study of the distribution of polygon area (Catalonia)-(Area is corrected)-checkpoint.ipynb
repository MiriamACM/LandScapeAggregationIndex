# %%
import geopandas as gpd
from matplotlib import pyplot as plt

# %%
# Map of Catalonia with Fuel 1 (Polygon format)

# %%
CatFuel1P= gpd.read_file("/home/coca/Maps_TFM/Polygon/Catalonia/CatFuel1.geojson")

# %%
CatFuel1P
# Out:
#      Code_18 Remark     Area_Ha          ID        AI     NOMCAT     CAPCAT  \
# 0        312   None   50.022927   EU_251094  0.843249  Catalunya  Barcelona
# 1        312   None   34.889415   EU_251095  0.654918  Catalunya  Barcelona
# 2        312   None  134.693603   EU_251096  1.000000  Catalunya  Barcelona
# 3        312   None   28.852283   EU_251097  0.625880  Catalunya  Barcelona
# 4        312   None   45.299020   EU_251098  0.423437  Catalunya  Barcelona
# ...      ...    ...         ...         ...       ...        ...        ...
# 2059     312   None   55.716594  EU_2362056  0.777835  Catalunya  Barcelona
# 2060     312   None   58.182562  EU_2362057  0.799186  Catalunya  Barcelona
# 2061     312   None   55.762077  EU_2362058  0.863239  Catalunya  Barcelona
# 2062     312   None  534.268595  EU_2362425  1.000000  Catalunya  Barcelona
# 2063     312   None  494.232002  EU_2362426  1.000000  Catalunya  Barcelona
#
# ...

# %%
x = CatFuel1P['Area_Ha']
x = pd.Series(x)
bins = [1.44658350e-01, 2.23277309e+03, 4.46540153e+03, 6.69802996e+03,
       8.93065840e+03, 1.11632868e+04, 1.33959153e+04, 1.56285437e+04,
       1.78611721e+04, 2.00938006e+04, 2.23264290e+04, 2.45590574e+04,
       2.67916859e+04, 2.90243143e+04, 3.12569427e+04, 3.34895712e+04,
       3.57221996e+04, 3.79548280e+04, 4.01874565e+04, 4.24200849e+04,
       4.46527133e+04, 4.68853418e+04, 4.91179702e+04, 5.13505987e+04,
       5.35832271e+04, 5.58158555e+04, 5.80484840e+04, 6.02811124e+04,
       6.25137408e+04, 6.47463693e+04, 6.69789977e+04, 6.92116261e+04,
       7.14442546e+04, 7.36768830e+04, 7.59095114e+04, 7.81421399e+04,
       8.03747683e+04, 8.26073967e+04, 8.48400252e+04, 8.70726536e+04,
       8.93052820e+04, 9.15379105e+04, 9.37705389e+04, 9.60031673e+04,
       9.82357958e+04, 1.00468424e+05, 1.02701053e+05, 1.04933681e+05,
       1.07166310e+05, 1.09398938e+05, 1.11631566e+05, 1.13864195e+05,
       1.16096823e+05, 1.18329452e+05, 1.20562080e+05, 1.22794709e+05,
       1.25027337e+05, 1.27259965e+05, 1.29492594e+05, 1.31725222e+05,
       1.33957851e+05, 1.36190479e+05, 1.38423108e+05, 1.40655736e+05,
       1.42888364e+05, 1.45120993e+05, 1.47353621e+05, 1.49586250e+05,
       1.51818878e+05, 1.54051507e+05, 1.56284135e+05, 1.58516764e+05,
       1.60749392e+05, 1.62982020e+05, 1.65214649e+05, 1.67447277e+05,
       1.69679906e+05, 1.71912534e+05, 1.74145163e+05, 1.76377791e+05,
       1.78610419e+05, 1.80843048e+05, 1.83075676e+05, 1.85308305e+05,
       1.87540933e+05, 1.89773562e+05, 1.92006190e+05, 1.94238818e+05,
       1.96471447e+05, 1.98704075e+05, 2.00936704e+05, 2.03169332e+05,
       2.05401961e+05, 2.07634589e+05, 2.09867218e+05, 2.12099846e+05,
       2.14332474e+05, 2.16565103e+05, 2.18797731e+05, 2.21030360e+05,
       2.23262988e+05]
logbins = np.logspace(np.log10(bins[0]),np.log10(bins[-1]),len(bins))
plt.hist(x, bins=logbins, edgecolor = 'black')
plt.xscale('log')


plt.ylabel('Number of polygons')
plt.xlabel('Area (Ha)')

plt.axvline(x=25, color = 'chartreuse' ,label = 'MW5x5')
plt.axvline(x=81, color = 'goldenrod' ,label = 'MW9x9')
plt.axvline(x=169, color = 'deeppink',label = 'MW13x13')
plt.axvline(x=239, color = 'blueviolet' ,label = 'MW17x17')
plt.axvline(x=441, color = 'cornflowerblue',label = 'MW21x21')
plt.axvline(x=625, color = 'darkcyan',label = 'MW25x25')

plt.legend(bbox_to_anchor = (1.0, 1), loc = 'upper left')

plt.grid()
plt.show()

# %%
# Map of Catalonia with Fuel 2 (Polygon format)

# %%
CatFuel2P= gpd.read_file("/home/coca/Maps_TFM/Polygon/Catalonia/CatFuel2.geojson")

# %%
CatFuel2P
# Out:
#     Code_18 Remark      Area_Ha          ID        AI     NOMCAT     CAPCAT  \
# 0       313   None    32.504641   EU_251474  0.820396  Catalunya  Barcelona
# 1       313   None   135.523292   EU_251479  0.855190  Catalunya  Barcelona
# 2       313   None    57.085766   EU_251484  0.841445  Catalunya  Barcelona
# 3       313   None  1950.285709   EU_251485  1.000000  Catalunya  Barcelona
# 4       313   None    25.382243   EU_251487  0.732109  Catalunya  Barcelona
# ..      ...    ...          ...         ...       ...        ...        ...
# 242     313   None   332.329195   EU_293079  1.000000  Catalunya  Barcelona
# 243     313   None    26.864586   EU_293080  0.828944  Catalunya  Barcelona
# 244     313   None    74.602252   EU_293082  0.967614  Catalunya  Barcelona
# 245     313   None   513.760479  EU_2361941  1.000000  Catalunya  Barcelona
# 246     313   None    67.214963  EU_2362059  0.877721  Catalunya  Barcelona
#
# ...

# %%
x = CatFuel2P['Area_Ha']
x = pd.Series(x)
bins = [   2.57400376,   22.05112082,   41.52823787,   61.00535492,
         80.48247197,   99.95958902,  119.43670607,  138.91382312,
        158.39094017,  177.86805722,  197.34517427,  216.82229132,
        236.29940837,  255.77652542,  275.25364247,  294.73075952,
        314.20787657,  333.68499362,  353.16211067,  372.63922772,
        392.11634477,  411.59346182,  431.07057887,  450.54769592,
        470.02481297,  489.50193002,  508.97904707,  528.45616412,
        547.93328117,  567.41039822,  586.88751527,  606.36463232,
        625.84174937,  645.31886642,  664.79598347,  684.27310052,
        703.75021757,  723.22733462,  742.70445167,  762.18156872,
        781.65868577,  801.13580282,  820.61291987,  840.09003692,
        859.56715397,  879.04427102,  898.52138807,  917.99850512,
        937.47562217,  956.95273922,  976.42985628,  995.90697333,
       1015.38409038, 1034.86120743, 1054.33832448, 1073.81544153,
       1093.29255858, 1112.76967563, 1132.24679268, 1151.72390973,
       1171.20102678, 1190.67814383, 1210.15526088, 1229.63237793,
       1249.10949498, 1268.58661203, 1288.06372908, 1307.54084613,
       1327.01796318, 1346.49508023, 1365.97219728, 1385.44931433,
       1404.92643138, 1424.40354843, 1443.88066548, 1463.35778253,
       1482.83489958, 1502.31201663, 1521.78913368, 1541.26625073,
       1560.74336778, 1580.22048483, 1599.69760188, 1619.17471893,
       1638.65183598, 1658.12895303, 1677.60607008, 1697.08318713,
       1716.56030418, 1736.03742123, 1755.51453828, 1774.99165533,
       1794.46877238, 1813.94588943, 1833.42300648, 1852.90012353,
       1872.37724058, 1891.85435763, 1911.33147468, 1930.80859173,
       1950.28570879]
logbins = np.logspace(np.log10(bins[0]),np.log10(bins[-1]),len(bins))
plt.hist(x, bins=logbins, edgecolor = 'black')
plt.xscale('log')
plt.ylabel('Number of polygons')
plt.xlabel('Area (Ha)')

plt.axvline(x=25, color = 'chartreuse' ,label = 'MW5x5')
plt.axvline(x=81, color = 'goldenrod' ,label = 'MW9x9')
plt.axvline(x=169, color = 'deeppink',label = 'MW13x13')
plt.axvline(x=239, color = 'blueviolet' ,label = 'MW17x17')
plt.axvline(x=441, color = 'cornflowerblue',label = 'MW21x21')
plt.axvline(x=625, color = 'darkcyan',label = 'MW25x25')

plt.legend(bbox_to_anchor = (1.0, 1), loc = 'upper left')

plt.grid()
plt.show()

# %%
# Map of Catalonia with Fuel 3 (Polygon format)

# %%
CatFuel3P= gpd.read_file("/home/coca/Maps_TFM/Polygon/Catalonia/CatFuel3.geojson")

# %%
CatFuel3P
# Out:
#      Code_18 Remark      Area_Ha          ID        AI     NOMCAT     CAPCAT  \
# 0        323   None   231.349526   EU_118385  1.000000  Catalunya  Barcelona
# 1        311   None    44.953952   EU_250989  1.000000  Catalunya  Barcelona
# 2        311   None    62.265554   EU_250990  1.000000  Catalunya  Barcelona
# 3        311   None    60.186983   EU_250991  1.000000  Catalunya  Barcelona
# 4        311   None    96.412774   EU_250995  1.000000  Catalunya  Barcelona
# ...      ...    ...          ...         ...       ...        ...        ...
# 4053     311   None  2036.590729  EU_2362416  1.000000  Catalunya  Barcelona
# 4054     321   None   364.661782  EU_2362434  1.000000  Catalunya  Barcelona
# 4055     321   None   352.662349  EU_2362435  1.000000  Catalunya  Barcelona
# 4056     323   None    39.436641  EU_2362445  0.834836  Catalunya  Barcelona
# 4057     324   None    78.700990  EU_2362449  1.000000  Catalunya  Barcelona
#
# ...

# %%
x = CatFuel3P['Area_Ha']
x = pd.Series(x)
bins = [1.17690810e-01, 2.73741480e+03, 5.47471191e+03, 8.21200901e+03,
       1.09493061e+04, 1.36866032e+04, 1.64239003e+04, 1.91611974e+04,
       2.18984945e+04, 2.46357917e+04, 2.73730888e+04, 3.01103859e+04,
       3.28476830e+04, 3.55849801e+04, 3.83222772e+04, 4.10595743e+04,
       4.37968714e+04, 4.65341685e+04, 4.92714656e+04, 5.20087627e+04,
       5.47460598e+04, 5.74833569e+04, 6.02206541e+04, 6.29579512e+04,
       6.56952483e+04, 6.84325454e+04, 7.11698425e+04, 7.39071396e+04,
       7.66444367e+04, 7.93817338e+04, 8.21190309e+04, 8.48563280e+04,
       8.75936251e+04, 9.03309222e+04, 9.30682193e+04, 9.58055164e+04,
       9.85428136e+04, 1.01280111e+05, 1.04017408e+05, 1.06754705e+05,
       1.09492002e+05, 1.12229299e+05, 1.14966596e+05, 1.17703893e+05,
       1.20441190e+05, 1.23178488e+05, 1.25915785e+05, 1.28653082e+05,
       1.31390379e+05, 1.34127676e+05, 1.36864973e+05, 1.39602270e+05,
       1.42339567e+05, 1.45076864e+05, 1.47814161e+05, 1.50551459e+05,
       1.53288756e+05, 1.56026053e+05, 1.58763350e+05, 1.61500647e+05,
       1.64237944e+05, 1.66975241e+05, 1.69712538e+05, 1.72449835e+05,
       1.75187133e+05, 1.77924430e+05, 1.80661727e+05, 1.83399024e+05,
       1.86136321e+05, 1.88873618e+05, 1.91610915e+05, 1.94348212e+05,
       1.97085509e+05, 1.99822807e+05, 2.02560104e+05, 2.05297401e+05,
       2.08034698e+05, 2.10771995e+05, 2.13509292e+05, 2.16246589e+05,
       2.18983886e+05, 2.21721183e+05, 2.24458480e+05, 2.27195778e+05,
       2.29933075e+05, 2.32670372e+05, 2.35407669e+05, 2.38144966e+05,
       2.40882263e+05, 2.43619560e+05, 2.46356857e+05, 2.49094154e+05,
       2.51831452e+05, 2.54568749e+05, 2.57306046e+05, 2.60043343e+05,
       2.62780640e+05, 2.65517937e+05, 2.68255234e+05, 2.70992531e+05,
       2.73729828e+05]
logbins = np.logspace(np.log10(bins[0]),np.log10(bins[-1]),len(bins))
plt.hist(x, bins=logbins, edgecolor = 'black')
plt.xscale('log')
plt.ylabel('Number of polygons')
plt.xlabel('Area (Ha)')

plt.axvline(x=25, color = 'chartreuse' ,label = 'MW5x5')
plt.axvline(x=81, color = 'goldenrod' ,label = 'MW9x9')
plt.axvline(x=169, color = 'deeppink',label = 'MW13x13')
plt.axvline(x=239, color = 'blueviolet' ,label = 'MW17x17')
plt.axvline(x=441, color = 'cornflowerblue',label = 'MW21x21')
plt.axvline(x=625, color = 'darkcyan',label = 'MW25x25')

plt.legend(bbox_to_anchor = (1.0, 1), loc = 'upper left')

plt.grid()
plt.show()

# %%
# Map of Catalonia with Fuel 4 (Polygon format)

# %%
CatFuel4P= gpd.read_file("/home/coca/Maps_TFM/Polygon/Catalonia/CatFuel4.geojson")

# %%
CatFuel4P
# Out:
#     Code_18 Remark     Area_Ha          ID        AI     NOMCAT     CAPCAT  \
# 0       322   None   38.021029   EU_259715  0.899408  Catalunya  Barcelona
# 1       322   None  278.036192   EU_259716  1.000000  Catalunya  Barcelona
# 2       322   None  589.643462   EU_259717  1.000000  Catalunya  Barcelona
# 3       322   None  551.364890   EU_259718  1.000000  Catalunya  Barcelona
# 4       322   None   98.319533   EU_259719  0.888847  Catalunya  Barcelona
# ..      ...    ...         ...         ...       ...        ...        ...
# 669     322   None    0.107275   EU_293782  0.000000  Catalunya  Barcelona
# 670     322   None  226.883139   EU_295348  0.979488  Catalunya  Barcelona
# 671     322   None   75.593218   EU_295349  0.989515  Catalunya  Barcelona
# 672     322   None   78.178252  EU_2362441  0.970517  Catalunya  Barcelona
# 673     322   None  119.804729  EU_2362442  0.875906  Catalunya  Barcelona
#
#       AREACA5000                                           geometry
# ...

# %%
x = CatFuel4P['Area_Ha']
x = pd.Series(x)
bins = [1.07274895e-01, 8.51363123e+01, 1.70165350e+02, 2.55194387e+02,
       3.40223425e+02, 4.25252462e+02, 5.10281500e+02, 5.95310537e+02,
       6.80339574e+02, 7.65368612e+02, 8.50397649e+02, 9.35426687e+02,
       1.02045572e+03, 1.10548476e+03, 1.19051380e+03, 1.27554284e+03,
       1.36057187e+03, 1.44560091e+03, 1.53062995e+03, 1.61565899e+03,
       1.70068802e+03, 1.78571706e+03, 1.87074610e+03, 1.95577514e+03,
       2.04080417e+03, 2.12583321e+03, 2.21086225e+03, 2.29589129e+03,
       2.38092032e+03, 2.46594936e+03, 2.55097840e+03, 2.63600744e+03,
       2.72103647e+03, 2.80606551e+03, 2.89109455e+03, 2.97612359e+03,
       3.06115262e+03, 3.14618166e+03, 3.23121070e+03, 3.31623973e+03,
       3.40126877e+03, 3.48629781e+03, 3.57132685e+03, 3.65635588e+03,
       3.74138492e+03, 3.82641396e+03, 3.91144300e+03, 3.99647203e+03,
       4.08150107e+03, 4.16653011e+03, 4.25155915e+03, 4.33658818e+03,
       4.42161722e+03, 4.50664626e+03, 4.59167530e+03, 4.67670433e+03,
       4.76173337e+03, 4.84676241e+03, 4.93179145e+03, 5.01682048e+03,
       5.10184952e+03, 5.18687856e+03, 5.27190760e+03, 5.35693663e+03,
       5.44196567e+03, 5.52699471e+03, 5.61202375e+03, 5.69705278e+03,
       5.78208182e+03, 5.86711086e+03, 5.95213990e+03, 6.03716893e+03,
       6.12219797e+03, 6.20722701e+03, 6.29225605e+03, 6.37728508e+03,
       6.46231412e+03, 6.54734316e+03, 6.63237219e+03, 6.71740123e+03,
       6.80243027e+03, 6.88745931e+03, 6.97248834e+03, 7.05751738e+03,
       7.14254642e+03, 7.22757546e+03, 7.31260449e+03, 7.39763353e+03,
       7.48266257e+03, 7.56769161e+03, 7.65272064e+03, 7.73774968e+03,
       7.82277872e+03, 7.90780776e+03, 7.99283679e+03, 8.07786583e+03,
       8.16289487e+03, 8.24792391e+03, 8.33295294e+03, 8.41798198e+03,
       8.50301102e+03]
logbins = np.logspace(np.log10(bins[0]),np.log10(bins[-1]),len(bins))
plt.hist(x, bins=logbins, edgecolor = 'black')
plt.xscale('log')
plt.ylabel('Number of polygons')
plt.xlabel('Area (Ha)')

plt.axvline(x=25, color = 'chartreuse' ,label = 'MW5x5')
plt.axvline(x=81, color = 'goldenrod' ,label = 'MW9x9')
plt.axvline(x=169, color = 'deeppink',label = 'MW13x13')
plt.axvline(x=239, color = 'blueviolet' ,label = 'MW17x17')
plt.axvline(x=441, color = 'cornflowerblue',label = 'MW21x21')
plt.axvline(x=625, color = 'darkcyan',label = 'MW25x25')

plt.legend(bbox_to_anchor = (1.0, 1), loc = 'upper left')

plt.grid()
plt.show()

# %%
# Map of Catalonia with Fuel 5 (Polygon format)

# %%
CatFuel5P= gpd.read_file("/home/coca/Maps_TFM/Polygon/Catalonia/CatFuel5.geojson")

# %%
CatFuel5P
# Out:
#   Code_18 Remark     Area_Ha         ID        AI     NOMCAT     CAPCAT  \
# 0     411   None  475.368987  EU_252169  1.000000  Catalunya  Barcelona
# 1     411   None   87.655363  EU_252170  0.952770  Catalunya  Barcelona
# 2     411   None   27.026052  EU_252779  0.936190  Catalunya  Barcelona
# 3     411   None   29.428347  EU_256517  0.809644  Catalunya  Barcelona
# 4     411   None  172.882098  EU_256518  0.973817  Catalunya  Barcelona
# 5     411   None   27.619539  EU_295119  0.870152  Catalunya  Barcelona
#
#     AREACA5000                                           geometry
# 0  32103.99495  POLYGON ((303781.424 4502136.872, 303768.971 4...
# 1  32103.99495  POLYGON ((306798.966 4517484.135, 306810.882 4...
# 2  32103.99495  POLYGON ((419700.692 4571526.223, 419699.105 4...
# 3  32103.99495  POLYGON ((293272.046 4595293.788, 293276.649 4...
# 4  32103.99495  POLYGON ((293760.061 4598662.300, 293737.189 4...
# 5  32103.99495  POLYGON ((478639.474 4628154.984, 478651.678 4...

# %%
x = CatFuel5P['Area_Ha']
x = pd.Series(x)
plt.hist(x, bins=10, edgecolor = 'black')

#plt.title()
plt.ylabel('Number of polygons')
plt.xlabel('Area (Ha)')

plt.axvline(x=25, color = 'chartreuse' ,label = 'MW5x5')
plt.axvline(x=81, color = 'goldenrod' ,label = 'MW9x9')
plt.axvline(x=169, color = 'deeppink',label = 'MW13x13')
plt.axvline(x=239, color = 'blueviolet' ,label = 'MW17x17')
plt.axvline(x=441, color = 'cornflowerblue',label = 'MW21x21')
plt.axvline(x=625, color = 'darkcyan',label = 'MW25x25')

plt.legend(bbox_to_anchor = (1.0, 1), loc = 'upper left')

plt.grid()
plt.show()
