# %%
import geopandas as gpd
from matplotlib import pyplot as plt

# %%
# Map of Catalonia with Fuel 1 (Polygon format)

# %%
EUFuel1P= gpd.read_file("/home/coca/Maps_TFM/Polygon/Europe/fuelCategory1.geojson")

# %%
EUFuel1P
# Out:
#        Code_18 Remark        Area_Ha          ID        AI  \
# 0          312   None      72.277688     EU_2069  0.987781
# 1          312   None     337.134076     EU_2070  1.000000
# 2          312   None      26.704484     EU_2071  0.814626
# 3          312   None     344.902196     EU_2072  1.000000
# 4          312   None      28.552960     EU_2073  0.847657
# ...        ...    ...            ...         ...       ...
# 180131     312   None    1013.569214  EU_2375218  1.000000
# 180132     312   None     274.676520  EU_2375219  0.978393
# 180133     312   None     435.329982  EU_2375220  1.000000
# 180134     312   None     388.995481  EU_2375221  1.000000
# 180135     312   None  281006.843375  EU_2375222  1.000000
#
#                                                  geometry
# 0       MULTIPOLYGON (((1793695.560 962828.920, 179373...
# 1       MULTIPOLYGON (((1792220.310 964272.070, 179220...
# 2       MULTIPOLYGON (((1796616.040 967128.840, 179657...
# ...

# %%
x = EUFuel1P['Area_Ha']
x = pd.Series(x)
bins = [1.01338840e-01, 3.51707364e+04, 7.03413715e+04, 1.05512007e+05,
       1.40682642e+05, 1.75853277e+05, 2.11023912e+05, 2.46194547e+05,
       2.81365182e+05, 3.16535817e+05, 3.51706452e+05, 3.86877087e+05,
       4.22047722e+05, 4.57218357e+05, 4.92388993e+05, 5.27559628e+05,
       5.62730263e+05, 5.97900898e+05, 6.33071533e+05, 6.68242168e+05,
       7.03412803e+05, 7.38583438e+05, 7.73754073e+05, 8.08924708e+05,
       8.44095343e+05, 8.79265979e+05, 9.14436614e+05, 9.49607249e+05,
       9.84777884e+05, 1.01994852e+06, 1.05511915e+06, 1.09028979e+06,
       1.12546042e+06, 1.16063106e+06, 1.19580169e+06, 1.23097233e+06,
       1.26614296e+06, 1.30131360e+06, 1.33648423e+06, 1.37165487e+06,
       1.40682550e+06, 1.44199614e+06, 1.47716678e+06, 1.51233741e+06,
       1.54750805e+06, 1.58267868e+06, 1.61784932e+06, 1.65301995e+06,
       1.68819059e+06, 1.72336122e+06, 1.75853186e+06, 1.79370249e+06,
       1.82887313e+06, 1.86404376e+06, 1.89921440e+06, 1.93438503e+06,
       1.96955567e+06, 2.00472630e+06, 2.03989694e+06, 2.07506757e+06,
       2.11023821e+06, 2.14540884e+06, 2.18057948e+06, 2.21575011e+06,
       2.25092075e+06, 2.28609138e+06, 2.32126202e+06, 2.35643265e+06,
       2.39160329e+06, 2.42677392e+06, 2.46194456e+06, 2.49711519e+06,
       2.53228583e+06, 2.56745646e+06, 2.60262710e+06, 2.63779773e+06,
       2.67296837e+06, 2.70813900e+06, 2.74330964e+06, 2.77848027e+06,
       2.81365091e+06, 2.84882154e+06, 2.88399218e+06, 2.91916281e+06,
       2.95433345e+06, 2.98950408e+06, 3.02467472e+06, 3.05984535e+06,
       3.09501599e+06, 3.13018662e+06, 3.16535726e+06, 3.20052789e+06,
       3.23569853e+06, 3.27086916e+06, 3.30603980e+06, 3.34121043e+06,
       3.37638107e+06, 3.41155170e+06, 3.44672234e+06, 3.48189298e+06,
       3.51706361e+06]
logbins = np.logspace(np.log10(bins[0]),np.log10(bins[-1]),len(bins))
plt.hist(x, bins=logbins, edgecolor = 'black')
plt.xscale('log')


plt.ylabel('Number of polygons')
plt.xlabel('Area (Ha)')

plt.axvline(x=25, color = 'chartreuse' ,label = 'MW5x5')
plt.axvline(x=81, color = 'goldenrod' ,label = 'MW9x9')
plt.axvline(x=169, color = 'deeppink',label = 'MW13x13')
plt.axvline(x=239, color = 'blueviolet' ,label = 'MW17x17')
plt.axvline(x=441, color = 'cornflowerblue',label = 'MW21x21')
plt.axvline(x=625, color = 'darkcyan',label = 'MW25x25')

plt.legend(bbox_to_anchor = (1.0, 1), loc = 'upper left')

plt.grid()
plt.show()

# %%
# Map of Catalonia with Fuel 2 (Polygon format)

# %%
EUFuel2P = gpd.read_file("/home/coca/Maps_TFM/Polygon/Europe/fuelCategory2.geojson")

# %%
EUFuel2P
# Out:
#        Code_18 Remark      Area_Ha          ID        AI  \
# 0          313   None  1182.239301     EU_2181  1.000000
# 1          313   None  1191.591505     EU_2182  1.000000
# 2          313   None  1203.839771     EU_2183  1.000000
# 3          313   None    72.359352     EU_2184  0.907444
# 4          313   None    52.395562     EU_2185  0.875723
# ...        ...    ...          ...         ...       ...
# 192597     313   None    27.626204  EU_2375245  0.926890
# 192598     313   None  1554.352609  EU_2375246  1.000000
# 192599     313   None    37.261825  EU_2375247  0.928291
# 192600     313   None    43.089625  EU_2375248  0.963729
# 192601     313   None    27.953190  EU_2375249  0.930984
#
#                                                  geometry
# 0       MULTIPOLYGON (((1724518.070 1040233.860, 17245...
# 1       MULTIPOLYGON (((1648092.430 1041782.400, 16480...
# 2       MULTIPOLYGON (((1652337.130 1043084.630, 16523...
# ...

# %%
x = EUFuel2P['Area_Ha']
x = pd.Series(x)
bins = [1.03160605e-01, 1.49895841e+03, 2.99781366e+03, 4.49666891e+03,
       5.99552416e+03, 7.49437941e+03, 8.99323466e+03, 1.04920899e+04,
       1.19909452e+04, 1.34898004e+04, 1.49886557e+04, 1.64875109e+04,
       1.79863662e+04, 1.94852214e+04, 2.09840767e+04, 2.24829319e+04,
       2.39817872e+04, 2.54806424e+04, 2.69794977e+04, 2.84783529e+04,
       2.99772082e+04, 3.14760634e+04, 3.29749187e+04, 3.44737739e+04,
       3.59726292e+04, 3.74714844e+04, 3.89703397e+04, 4.04691949e+04,
       4.19680502e+04, 4.34669054e+04, 4.49657607e+04, 4.64646159e+04,
       4.79634712e+04, 4.94623264e+04, 5.09611817e+04, 5.24600369e+04,
       5.39588922e+04, 5.54577474e+04, 5.69566027e+04, 5.84554579e+04,
       5.99543132e+04, 6.14531684e+04, 6.29520237e+04, 6.44508789e+04,
       6.59497342e+04, 6.74485894e+04, 6.89474447e+04, 7.04462999e+04,
       7.19451552e+04, 7.34440104e+04, 7.49428657e+04, 7.64417209e+04,
       7.79405762e+04, 7.94394314e+04, 8.09382867e+04, 8.24371419e+04,
       8.39359972e+04, 8.54348524e+04, 8.69337077e+04, 8.84325629e+04,
       8.99314182e+04, 9.14302734e+04, 9.29291287e+04, 9.44279839e+04,
       9.59268392e+04, 9.74256944e+04, 9.89245497e+04, 1.00423405e+05,
       1.01922260e+05, 1.03421115e+05, 1.04919971e+05, 1.06418826e+05,
       1.07917681e+05, 1.09416536e+05, 1.10915392e+05, 1.12414247e+05,
       1.13913102e+05, 1.15411957e+05, 1.16910813e+05, 1.18409668e+05,
       1.19908523e+05, 1.21407378e+05, 1.22906234e+05, 1.24405089e+05,
       1.25903944e+05, 1.27402799e+05, 1.28901655e+05, 1.30400510e+05,
       1.31899365e+05, 1.33398220e+05, 1.34897076e+05, 1.36395931e+05,
       1.37894786e+05, 1.39393641e+05, 1.40892497e+05, 1.42391352e+05,
       1.43890207e+05, 1.45389062e+05, 1.46887918e+05, 1.48386773e+05,
       1.49885628e+05]
logbins = np.logspace(np.log10(bins[0]),np.log10(bins[-1]),len(bins))
plt.hist(x, bins=logbins, edgecolor = 'black')
plt.xscale('log')
plt.ylabel('Number of polygons')
plt.xlabel('Area (Ha)')

plt.axvline(x=25, color = 'chartreuse' ,label = 'MW5x5')
plt.axvline(x=81, color = 'goldenrod' ,label = 'MW9x9')
plt.axvline(x=169, color = 'deeppink',label = 'MW13x13')
plt.axvline(x=239, color = 'blueviolet' ,label = 'MW17x17')
plt.axvline(x=441, color = 'cornflowerblue',label = 'MW21x21')
plt.axvline(x=625, color = 'darkcyan',label = 'MW25x25')

plt.legend(bbox_to_anchor = (1.0, 1), loc = 'upper left')

plt.grid()
plt.show()

# %%
# Map of Catalonia with Fuel 3 (Polygon format)

# %%
EUFuel3P= gpd.read_file("/home/coca/Maps_TFM/Polygon/Europe/fuelCategory3.geojson")

# %%
EUFuel3P
# Out:
#        Code_18 Remark     Area_Ha          ID        AI  \
# 0          311   None   40.522687     EU_1956  0.955981
# 1          311   None   30.188253     EU_1957  1.000000
# 2          311   None   43.399247     EU_1958  0.887013
# 3          311   None   62.643680     EU_1959  1.000000
# 4          311   None  245.534941     EU_1960  1.000000
# ...        ...    ...         ...         ...       ...
# 578185     324   None  125.412955  EU_2375306  0.976259
# 578186     324   None   40.378539  EU_2375307  0.972230
# 578187     324   None   56.625518  EU_2375308  0.982954
# 578188     324   None   46.006148  EU_2375309  0.981452
# 578189     324   None   29.240824  EU_2375310  0.931446
#
#                                                  geometry
# 0       MULTIPOLYGON (((1816944.830 963047.400, 181688...
# 1       MULTIPOLYGON (((1799232.250 966392.870, 179922...
# 2       MULTIPOLYGON (((1798787.290 967542.800, 179863...
# ...

# %%
x = EUFuel3P['Area_Ha']
x = pd.Series(x)
bins = [1.00106670e-01, 8.16756740e+03, 1.63350347e+04, 2.45025020e+04,
       3.26699693e+04, 4.08374366e+04, 4.90049039e+04, 5.71723712e+04,
       6.53398385e+04, 7.35073058e+04, 8.16747731e+04, 8.98422404e+04,
       9.80097077e+04, 1.06177175e+05, 1.14344642e+05, 1.22512110e+05,
       1.30679577e+05, 1.38847044e+05, 1.47014511e+05, 1.55181979e+05,
       1.63349446e+05, 1.71516913e+05, 1.79684381e+05, 1.87851848e+05,
       1.96019315e+05, 2.04186782e+05, 2.12354250e+05, 2.20521717e+05,
       2.28689184e+05, 2.36856652e+05, 2.45024119e+05, 2.53191586e+05,
       2.61359054e+05, 2.69526521e+05, 2.77693988e+05, 2.85861455e+05,
       2.94028923e+05, 3.02196390e+05, 3.10363857e+05, 3.18531325e+05,
       3.26698792e+05, 3.34866259e+05, 3.43033727e+05, 3.51201194e+05,
       3.59368661e+05, 3.67536128e+05, 3.75703596e+05, 3.83871063e+05,
       3.92038530e+05, 4.00205998e+05, 4.08373465e+05, 4.16540932e+05,
       4.24708399e+05, 4.32875867e+05, 4.41043334e+05, 4.49210801e+05,
       4.57378269e+05, 4.65545736e+05, 4.73713203e+05, 4.81880671e+05,
       4.90048138e+05, 4.98215605e+05, 5.06383072e+05, 5.14550540e+05,
       5.22718007e+05, 5.30885474e+05, 5.39052942e+05, 5.47220409e+05,
       5.55387876e+05, 5.63555344e+05, 5.71722811e+05, 5.79890278e+05,
       5.88057745e+05, 5.96225213e+05, 6.04392680e+05, 6.12560147e+05,
       6.20727615e+05, 6.28895082e+05, 6.37062549e+05, 6.45230016e+05,
       6.53397484e+05, 6.61564951e+05, 6.69732418e+05, 6.77899886e+05,
       6.86067353e+05, 6.94234820e+05, 7.02402288e+05, 7.10569755e+05,
       7.18737222e+05, 7.26904689e+05, 7.35072157e+05, 7.43239624e+05,
       7.51407091e+05, 7.59574559e+05, 7.67742026e+05, 7.75909493e+05,
       7.84076960e+05, 7.92244428e+05, 8.00411895e+05, 8.08579362e+05,
       8.16746830e+05]
logbins = np.logspace(np.log10(bins[0]),np.log10(bins[-1]),len(bins))
plt.hist(x, bins=logbins, edgecolor = 'black')
plt.xscale('log')
plt.ylabel('Number of polygons')
plt.xlabel('Area (Ha)')

plt.axvline(x=25, color = 'chartreuse' ,label = 'MW5x5')
plt.axvline(x=81, color = 'goldenrod' ,label = 'MW9x9')
plt.axvline(x=169, color = 'deeppink',label = 'MW13x13')
plt.axvline(x=239, color = 'blueviolet' ,label = 'MW17x17')
plt.axvline(x=441, color = 'cornflowerblue',label = 'MW21x21')
plt.axvline(x=625, color = 'darkcyan',label = 'MW25x25')

plt.legend(bbox_to_anchor = (1.0, 1), loc = 'upper left')

plt.grid()
plt.show()

# %%
# Map of Catalonia with Fuel 4 (Polygon format)

# %%
EUFuel4P= gpd.read_file("/home/coca/Maps_TFM/Polygon/Europe/fuelCategory4.geojson")

# %%
EUFuel4P
# Out:
#       Code_18 Remark      Area_Ha          ID        AI  \
# 0         322   None    43.869606     EU_2386  0.949831
# 1         322   None    25.228159     EU_2387  0.951801
# 2         322   None   261.702549     EU_2388  1.000000
# 3         322   None    82.536750     EU_2389  0.959541
# 4         322   None   158.483485     EU_2390  1.000000
# ...       ...    ...          ...         ...       ...
# 46816     322   None    79.445285  EU_2375282  0.926817
# 46817     322   None   363.860526  EU_2375283  1.000000
# 46818     322   None    78.859447  EU_2375284  0.965459
# 46819     322   None   931.377104  EU_2375285  1.000000
# 46820     322   None  1645.354325  EU_2375286  1.000000
#
#                                                 geometry
# 0      MULTIPOLYGON (((1800375.730 988867.000, 180035...
# 1      MULTIPOLYGON (((1564314.340 1029987.220, 15642...
# 2      MULTIPOLYGON (((1648805.200 1042371.290, 16487...
# 3      MULTIPOLYGON (((1652918.760 1043037.920, 16528...
# ...

# %%
x = EUFuel4P['Area_Ha']
x = pd.Series(x)
bins = [1.07274895e-01, 7.96340090e+03, 1.59266945e+04, 2.38899881e+04,
       3.18532818e+04, 3.98165754e+04, 4.77798690e+04, 5.57431626e+04,
       6.37064563e+04, 7.16697499e+04, 7.96330435e+04, 8.75963371e+04,
       9.55596308e+04, 1.03522924e+05, 1.11486218e+05, 1.19449512e+05,
       1.27412805e+05, 1.35376099e+05, 1.43339392e+05, 1.51302686e+05,
       1.59265980e+05, 1.67229273e+05, 1.75192567e+05, 1.83155861e+05,
       1.91119154e+05, 1.99082448e+05, 2.07045741e+05, 2.15009035e+05,
       2.22972329e+05, 2.30935622e+05, 2.38898916e+05, 2.46862210e+05,
       2.54825503e+05, 2.62788797e+05, 2.70752090e+05, 2.78715384e+05,
       2.86678678e+05, 2.94641971e+05, 3.02605265e+05, 3.10568559e+05,
       3.18531852e+05, 3.26495146e+05, 3.34458439e+05, 3.42421733e+05,
       3.50385027e+05, 3.58348320e+05, 3.66311614e+05, 3.74274908e+05,
       3.82238201e+05, 3.90201495e+05, 3.98164788e+05, 4.06128082e+05,
       4.14091376e+05, 4.22054669e+05, 4.30017963e+05, 4.37981257e+05,
       4.45944550e+05, 4.53907844e+05, 4.61871137e+05, 4.69834431e+05,
       4.77797725e+05, 4.85761018e+05, 4.93724312e+05, 5.01687606e+05,
       5.09650899e+05, 5.17614193e+05, 5.25577486e+05, 5.33540780e+05,
       5.41504074e+05, 5.49467367e+05, 5.57430661e+05, 5.65393955e+05,
       5.73357248e+05, 5.81320542e+05, 5.89283835e+05, 5.97247129e+05,
       6.05210423e+05, 6.13173716e+05, 6.21137010e+05, 6.29100304e+05,
       6.37063597e+05, 6.45026891e+05, 6.52990184e+05, 6.60953478e+05,
       6.68916772e+05, 6.76880065e+05, 6.84843359e+05, 6.92806653e+05,
       7.00769946e+05, 7.08733240e+05, 7.16696533e+05, 7.24659827e+05,
       7.32623121e+05, 7.40586414e+05, 7.48549708e+05, 7.56513002e+05,
       7.64476295e+05, 7.72439589e+05, 7.80402882e+05, 7.88366176e+05,
       7.96329470e+05]
logbins = np.logspace(np.log10(bins[0]),np.log10(bins[-1]),len(bins))
plt.hist(x, bins=logbins, edgecolor = 'black')
plt.xscale('log')
plt.ylabel('Number of polygons')
plt.xlabel('Area (Ha)')

plt.axvline(x=25, color = 'chartreuse' ,label = 'MW5x5')
plt.axvline(x=81, color = 'goldenrod' ,label = 'MW9x9')
plt.axvline(x=169, color = 'deeppink',label = 'MW13x13')
plt.axvline(x=239, color = 'blueviolet' ,label = 'MW17x17')
plt.axvline(x=441, color = 'cornflowerblue',label = 'MW21x21')
plt.axvline(x=625, color = 'darkcyan',label = 'MW25x25')

plt.legend(bbox_to_anchor = (1.0, 1), loc = 'upper left')

plt.grid()
plt.show()

# %%
# Map of Catalonia with Fuel 5 (Polygon format)

# %%
EUFuel5P= gpd.read_file("/home/coca/Maps_TFM/Polygon/Europe/fuelCategory5.geojson")

# %%
EUFuel5P
# Out:
#      Code_18 Remark     Area_Ha          ID        AI  \
# 0        411   None  553.273089    EU_11080  1.000000
# 1        411   None   44.522306    EU_11081  0.974586
# 2        411   None   26.957928    EU_11082  0.749477
# 3        411   None   41.307097    EU_11083  0.934103
# 4        411   None   49.669618    EU_11084  0.889496
# ...      ...    ...         ...         ...       ...
# 9683     411   None   28.593086  EU_2373581  0.987356
# 9684     411   None   62.195456  EU_2373582  0.902577
# 9685     411   None   28.006168  EU_2373583  0.928399
# 9686     411   None   34.109846  EU_2373584  0.898104
# 9687     411   None  515.877760  EU_2373585  1.000000
#
#                                                geometry
# 0     MULTIPOLYGON (((2888062.700 1611747.530, 28880...
# 1     MULTIPOLYGON (((2873358.300 1633647.590, 28733...
# 2     MULTIPOLYGON (((2912990.130 1656957.400, 29129...
# 3     MULTIPOLYGON (((2911577.770 1656851.590, 29115...
# ...

# %%
x = EUFuel5P['Area_Ha']
x = pd.Series(x)
bins = [1.01137150e-01, 6.54493891e+02, 1.30888664e+03, 1.96327940e+03,
       2.61767215e+03, 3.27206490e+03, 3.92645766e+03, 4.58085041e+03,
       5.23524316e+03, 5.88963592e+03, 6.54402867e+03, 7.19842142e+03,
       7.85281418e+03, 8.50720693e+03, 9.16159968e+03, 9.81599244e+03,
       1.04703852e+04, 1.11247779e+04, 1.17791707e+04, 1.24335635e+04,
       1.30879562e+04, 1.37423490e+04, 1.43967417e+04, 1.50511345e+04,
       1.57055272e+04, 1.63599200e+04, 1.70143127e+04, 1.76687055e+04,
       1.83230982e+04, 1.89774910e+04, 1.96318837e+04, 2.02862765e+04,
       2.09406692e+04, 2.15950620e+04, 2.22494548e+04, 2.29038475e+04,
       2.35582403e+04, 2.42126330e+04, 2.48670258e+04, 2.55214185e+04,
       2.61758113e+04, 2.68302040e+04, 2.74845968e+04, 2.81389895e+04,
       2.87933823e+04, 2.94477750e+04, 3.01021678e+04, 3.07565605e+04,
       3.14109533e+04, 3.20653461e+04, 3.27197388e+04, 3.33741316e+04,
       3.40285243e+04, 3.46829171e+04, 3.53373098e+04, 3.59917026e+04,
       3.66460953e+04, 3.73004881e+04, 3.79548808e+04, 3.86092736e+04,
       3.92636663e+04, 3.99180591e+04, 4.05724518e+04, 4.12268446e+04,
       4.18812374e+04, 4.25356301e+04, 4.31900229e+04, 4.38444156e+04,
       4.44988084e+04, 4.51532011e+04, 4.58075939e+04, 4.64619866e+04,
       4.71163794e+04, 4.77707721e+04, 4.84251649e+04, 4.90795576e+04,
       4.97339504e+04, 5.03883431e+04, 5.10427359e+04, 5.16971287e+04,
       5.23515214e+04, 5.30059142e+04, 5.36603069e+04, 5.43146997e+04,
       5.49690924e+04, 5.56234852e+04, 5.62778779e+04, 5.69322707e+04,
       5.75866634e+04, 5.82410562e+04, 5.88954489e+04, 5.95498417e+04,
       6.02042345e+04, 6.08586272e+04, 6.15130200e+04, 6.21674127e+04,
       6.28218055e+04, 6.34761982e+04, 6.41305910e+04, 6.47849837e+04,
       6.54393765e+04]
logbins = np.logspace(np.log10(bins[0]),np.log10(bins[-1]),len(bins))
plt.hist(x, bins=logbins, edgecolor = 'black')
plt.xscale('log')
plt.ylabel('Number of polygons')
plt.xlabel('Area (Ha)')

plt.axvline(x=25, color = 'chartreuse' ,label = 'MW5x5')
plt.axvline(x=81, color = 'goldenrod' ,label = 'MW9x9')
plt.axvline(x=169, color = 'deeppink',label = 'MW13x13')
plt.axvline(x=239, color = 'blueviolet' ,label = 'MW17x17')
plt.axvline(x=441, color = 'cornflowerblue',label = 'MW21x21')
plt.axvline(x=625, color = 'darkcyan',label = 'MW25x25')

plt.legend(bbox_to_anchor = (1.0, 1), loc = 'upper left')

plt.grid()
plt.show()
