# %%
import geopandas as gpd
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

# %%
def poly_loghist(x, bins):
    hist, bins = np.histogram(x, bins=bins)
    logbins = np.logspace(np.log10(bins[0]),np.log10(bins[-1]),len(bins))
    plt.hist(x, bins=logbins,color ='cadetblue', edgecolor = 'black')
    plt.xscale('log')
    plt.yscale('log')
    plt.xlim(10**(-2),2*10**5)
    plt.ylim(0,10**3)
    plt.xlabel('Area (Ha)')
    plt.ylabel('Number of polygons')
    plt.grid()

# %%
# Map of Catalonia with Fuel 1 (Polygon format)
CatFuel1P= gpd.read_file("/home/coca/Maps_TFM/Polygon/Catalonia/CatFuel1.geojson")

# %%
# Modification of the Area of polygons
CatFuel1P.loc[:,'Area_Ha'] = CatFuel1P.area/10000

# %%
# Number of patches Vs. Area // Number of polygons Vs. Area
# Using lognormal distribution in the X axis 

fig, ax = plt.subplots(nrows = 1, ncols= 1, figsize=(10,5))

plt.subplot(1,2,2)
poly_loghist(CatFuel1P['Area_Ha'], 100)

plt.title ('Area distribution of Fuel Category 1 (Polygon)')

plt.tight_layout()
plt.show()

#plt.savefig("/home/coca/Maps_TFM/Raster/Output/Fuel1/AI_Dist_Fuel1.jpg")
# Out:
# /tmp/ipykernel_23091/1436925945.py:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,2,2)
# /tmp/ipykernel_23091/1622104253.py:8: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   plt.ylim(0,10**3)

# %%
# Map of Catalonia with Fuel 2 (Polygon format)
CatFuel2P= gpd.read_file("/home/coca/Maps_TFM/Polygon/Catalonia/CatFuel2.geojson")

# %%
# Modification of the Area of polygons
CatFuel2P.loc[:,'Area_Ha'] = CatFuel2P.area/10000

# %%
# Number of patches Vs. Area // Number of polygons Vs. Area
# Using lognormal distribution in the X axis 

fig, ax = plt.subplots(nrows = 1, ncols= 1, figsize=(10,5))

plt.subplot(1,2,2)
poly_loghist(CatFuel2P['Area_Ha'], 100)

plt.title ('Area distribution of Fuel Category 2 (Polygon)')

plt.tight_layout()
plt.show()

#plt.savefig("/home/coca/Maps_TFM/Raster/Output/Fuel1/AI_Dist_Fuel1.jpg")
# Out:
# /tmp/ipykernel_23091/203838927.py:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,2,2)
# /tmp/ipykernel_23091/1622104253.py:8: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   plt.ylim(0,10**3)

# %%
# Map of Catalonia with Fuel 3 (Polygon format)
CatFuel3P= gpd.read_file("/home/coca/Maps_TFM/Polygon/Catalonia/CatFuel3.geojson")

# %%
# Modification of the Area of polygons
CatFuel3P.loc[:,'Area_Ha'] = CatFuel3P.area/10000

# %%
CatFuel3P['Area_Ha'].max()
# Out:
# 107958.13085819903

# %%
# Number of patches Vs. Area // Number of polygons Vs. Area
# Using lognormal distribution in the X axis 

fig, ax = plt.subplots(nrows = 1, ncols= 1, figsize=(10,5))

plt.subplot(1,2,2)
poly_loghist(CatFuel3P['Area_Ha'], 100)

plt.title ('Area distribution of Fuel Category 3 (Polygon)')

plt.tight_layout()
plt.show()

#plt.savefig("/home/coca/Maps_TFM/Raster/Output/Fuel1/AI_Dist_Fuel1.jpg")
# Out:
# /tmp/ipykernel_23091/851857035.py:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,2,2)
# /tmp/ipykernel_23091/1622104253.py:8: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   plt.ylim(0,10**3)

# %%
# Map of Catalonia with Fuel 4 (Polygon format)
CatFuel4P= gpd.read_file("/home/coca/Maps_TFM/Polygon/Catalonia/CatFuel4.geojson")

# %%
# Modification of the Area of polygons
CatFuel4P.loc[:,'Area_Ha'] = CatFuel4P.area/10000

# %%
# Number of patches Vs. Area // Number of polygons Vs. Area
# Using lognormal distribution in the X axis 

fig, ax = plt.subplots(nrows = 1, ncols= 1, figsize=(10,5))

plt.subplot(1,2,2)
poly_loghist(CatFuel4P['Area_Ha'], 100)

plt.title ('Area distribution of Fuel Category 4 (Polygon)')

plt.tight_layout()
plt.show()

#plt.savefig("/home/coca/Maps_TFM/Raster/Output/Fuel1/AI_Dist_Fuel1.jpg")
# Out:
# /tmp/ipykernel_23091/4264433196.py:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,2,2)
# /tmp/ipykernel_23091/1622104253.py:8: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   plt.ylim(0,10**3)

# %%
# Map of Catalonia with Fuel 5 (Polygon format)
CatFuel5P= gpd.read_file("/home/coca/Maps_TFM/Polygon/Catalonia/CatFuel5.geojson")

# %%
# Modification of the Area of polygons
CatFuel5P.loc[:,'Area_Ha'] = CatFuel5P.area/10000

# %%
# Number of patches Vs. Area // Number of polygons Vs. Area
# Using lognormal distribution in the X axis 

fig, ax = plt.subplots(nrows = 1, ncols= 1, figsize=(10,5))

plt.subplot(1,2,2)
poly_loghist(CatFuel5P['Area_Ha'], 100)

plt.title ('Area distribution of Fuel Category 5 (Polygon)')

plt.tight_layout()
plt.show()

#plt.savefig("/home/coca/Maps_TFM/Raster/Output/Fuel1/AI_Dist_Fuel1.jpg")
# Out:
# /tmp/ipykernel_23091/3363401012.py:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,2,2)
# /tmp/ipykernel_23091/1622104253.py:8: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   plt.ylim(0,10**3)
