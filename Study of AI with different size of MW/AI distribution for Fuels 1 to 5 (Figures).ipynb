# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Distribution of the aggregation Index of Fuel 1 when using MW5

# %%
AIMW5Fuel1 = pd.read_pickle("/home/coca/Maps_TFM/Raster/Output/Fuel1/AIMW5Fuel1.pkl")
AIMW9Fuel1  = pd.read_pickle("/home/coca/Maps_TFM/Raster/Output/Fuel1/AIMW9Fuel1.pkl")
AIMW13Fuel1  = pd.read_pickle("/home/coca/Maps_TFM/Raster/Output/Fuel1/AIMW13Fuel1.pkl")
AIMW17Fuel1  = pd.read_pickle("/home/coca/Maps_TFM/Raster/Output/Fuel1/AIMW17Fuel1.pkl")
AIMW21Fuel1  = pd.read_pickle("/home/coca/Maps_TFM/Raster/Output/Fuel1/AIMW21Fuel1.pkl")
AIMW25Fuel1  = pd.read_pickle("/home/coca/Maps_TFM/Raster/Output/Fuel1/AIMW25Fuel1.pkl")

# %%
fig = plt.figure(figsize=(10,15))
fig.subplots_adjust(hspace = 0.3, wspace=0.3)

ax1 = fig.add_subplot(3, 2, 1)
ax2 = fig.add_subplot(3, 2, 2)
ax3 = fig.add_subplot(3, 2, 3)
ax4 = fig.add_subplot(3, 2, 4)
ax5 = fig.add_subplot(3, 2, 5)
ax6 = fig.add_subplot(3, 2, 6)
 
ax1.hist(AIMW5Fuel1['AI'], bins=[0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue", edgecolor= 'black')
ax2.hist(AIMW9Fuel1['AI'], bins= [0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax3.hist(AIMW13Fuel1['AI'], bins=[0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax4.hist(AIMW17Fuel1['AI'], bins= [0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax5.hist(AIMW21Fuel1['AI'], bins=[0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax6.hist(AIMW25Fuel1['AI'], bins= [0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')

ax1.set_ylim(0, 600000)
ax2.set_ylim(0, 600000)
ax3.set_ylim(0, 600000)
ax4.set_ylim(0, 600000)
ax5.set_ylim(0, 600000)
ax6.set_ylim(0, 600000)

ax1.set_xlabel('Aggregation Index')
ax2.set_xlabel('Aggregation Index')
ax3.set_xlabel('Aggregation Index')
ax4.set_xlabel('Aggregation Index')
ax5.set_xlabel('Aggregation Index')
ax6.set_xlabel('Aggregation Index')

ax1.set_ylabel('Number of cells')
ax2.set_ylabel('Number of cells')
ax3.set_ylabel('Number of cells')
ax4.set_ylabel('Number of cells')
ax5.set_ylabel('Number of cells')
ax6.set_ylabel('Number of cells')

ax1.set_title('AI distribution of Fuel 1 (MW5)')
ax2.set_title('AI distribution of Fuel 1 (MW9)')
ax3.set_title('AI distribution of Fuel 1 (MW13)')
ax4.set_title('AI distribution of Fuel 1 (MW17)')
ax5.set_title('AI distribution of Fuel 1 (MW21)')
ax6.set_title('AI distribution of Fuel 1 (MW25)')

ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()
ax5.grid()
ax6.grid()

#plt.show()

plt.savefig("/home/coca/Maps_TFM/Raster/Output/Fuel1/AI_Dist_Fuel1.jpg")

# %%
# Distribution of the aggregation Index of Fuel 2 when using MW5

# %%
AIMW5Fuel2 = pd.read_pickle("/home/coca/Maps_TFM/Raster/Output/Fuel2/AIMW5Fuel2.pkl")
AIMW9Fuel2  = pd.read_pickle("/home/coca/Maps_TFM/Raster/Output/Fuel2/AIMW9Fuel2.pkl")
AIMW13Fuel2  = pd.read_pickle("/home/coca/Maps_TFM/Raster/Output/Fuel2/AIMW13Fuel2.pkl")
AIMW17Fuel2  = pd.read_pickle("/home/coca/Maps_TFM/Raster/Output/Fuel2/AIMW17Fuel2.pkl")
AIMW21Fuel2  = pd.read_pickle("/home/coca/Maps_TFM/Raster/Output/Fuel2/AIMW21Fuel2.pkl")
AIMW25Fuel2  = pd.read_pickle("/home/coca/Maps_TFM/Raster/Output/Fuel2/AIMW25Fuel2.pkl")

# %%
fig = plt.figure(figsize=(10,15))
fig.subplots_adjust(hspace = 0.3, wspace=0.3)

ax1 = fig.add_subplot(3, 2, 1)
ax2 = fig.add_subplot(3, 2, 2)
ax3 = fig.add_subplot(3, 2, 3)
ax4 = fig.add_subplot(3, 2, 4)
ax5 = fig.add_subplot(3, 2, 5)
ax6 = fig.add_subplot(3, 2, 6)
 
ax1.hist(AIMW5Fuel2['AI'], bins=[0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue", edgecolor= 'black')
ax2.hist(AIMW9Fuel2['AI'], bins= [0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax3.hist(AIMW13Fuel2['AI'], bins=[0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax4.hist(AIMW17Fuel2['AI'], bins= [0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax5.hist(AIMW21Fuel2['AI'], bins=[0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax6.hist(AIMW25Fuel2['AI'], bins= [0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')

ax1.set_ylim(0, 6000)
ax2.set_ylim(0, 6000)
ax3.set_ylim(0, 6000)
ax4.set_ylim(0, 6000)
ax5.set_ylim(0, 6000)
ax6.set_ylim(0, 6000)

ax1.set_xlabel('Aggregation Index')
ax2.set_xlabel('Aggregation Index')
ax3.set_xlabel('Aggregation Index')
ax4.set_xlabel('Aggregation Index')
ax5.set_xlabel('Aggregation Index')
ax6.set_xlabel('Aggregation Index')

ax1.set_ylabel('Number of cells')
ax2.set_ylabel('Number of cells')
ax3.set_ylabel('Number of cells')
ax4.set_ylabel('Number of cells')
ax5.set_ylabel('Number of cells')
ax6.set_ylabel('Number of cells')

ax1.set_title('AI distribution of Fuel 2 (MW5)')
ax2.set_title('AI distribution of Fuel 2 (MW9)')
ax3.set_title('AI distribution of Fuel 2 (MW13)')
ax4.set_title('AI distribution of Fuel 2 (MW17)')
ax5.set_title('AI distribution of Fuel 2 (MW21)')
ax6.set_title('AI distribution of Fuel 2 (MW25)')

ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()
ax5.grid()
ax6.grid()

#plt.show()

plt.savefig("/home/coca/Maps_TFM/Raster/Output/Fuel2/AI_Dist_Fuel2.jpg")

# %%
# Distribution of the aggregation Index of Fuel 3 when using MW5

# %%
AIMW5Fuel3 = pd.read_pickle("/home/coca/Maps_TFM/Raster/Output/Fuel3/AIMW5Fuel3.pkl")
AIMW9Fuel3  = pd.read_pickle("/home/coca/Maps_TFM/Raster/Output/Fuel3/AIMW9Fuel3.pkl")
AIMW13Fuel3  = pd.read_pickle("/home/coca/Maps_TFM/Raster/Output/Fuel3/AIMW13Fuel3.pkl")
AIMW17Fuel3  = pd.read_pickle("/home/coca/Maps_TFM/Raster/Output/Fuel3/AIMW17Fuel3.pkl")
AIMW21Fuel3  = pd.read_pickle("/home/coca/Maps_TFM/Raster/Output/Fuel3/AIMW21Fuel3.pkl")
AIMW25Fuel3  = pd.read_pickle("/home/coca/Maps_TFM/Raster/Output/Fuel3/AIMW25Fuel3.pkl")

# %%
fig = plt.figure(figsize=(10,15))
fig.subplots_adjust(hspace = 0.3, wspace=0.3)

ax1 = fig.add_subplot(3, 2, 1)
ax2 = fig.add_subplot(3, 2, 2)
ax3 = fig.add_subplot(3, 2, 3)
ax4 = fig.add_subplot(3, 2, 4)
ax5 = fig.add_subplot(3, 2, 5)
ax6 = fig.add_subplot(3, 2, 6)
 
ax1.hist(AIMW5Fuel3['AI'], bins=[0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue", edgecolor= 'black')
ax2.hist(AIMW9Fuel3['AI'], bins= [0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax3.hist(AIMW13Fuel3['AI'], bins=[0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax4.hist(AIMW17Fuel3['AI'], bins= [0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax5.hist(AIMW21Fuel3['AI'], bins=[0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax6.hist(AIMW25Fuel3['AI'], bins= [0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')

ax1.set_ylim(0, 800000)
ax2.set_ylim(0, 800000)
ax3.set_ylim(0, 800000)
ax4.set_ylim(0, 800000)
ax5.set_ylim(0, 800000)
ax6.set_ylim(0, 800000)

ax1.set_xlabel('Aggregation Index')
ax2.set_xlabel('Aggregation Index')
ax3.set_xlabel('Aggregation Index')
ax4.set_xlabel('Aggregation Index')
ax5.set_xlabel('Aggregation Index')
ax6.set_xlabel('Aggregation Index')

ax1.set_ylabel('Number of cells')
ax2.set_ylabel('Number of cells')
ax3.set_ylabel('Number of cells')
ax4.set_ylabel('Number of cells')
ax5.set_ylabel('Number of cells')
ax6.set_ylabel('Number of cells')

ax1.set_title('AI distribution of Fuel 3 (MW5)')
ax2.set_title('AI distribution of Fuel 3 (MW9)')
ax3.set_title('AI distribution of Fuel 3 (MW13)')
ax4.set_title('AI distribution of Fuel 3 (MW17)')
ax5.set_title('AI distribution of Fuel 3 (MW21)')
ax6.set_title('AI distribution of Fuel 3 (MW25)')

ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()
ax5.grid()
ax6.grid()

#plt.show()

plt.savefig("/home/coca/Maps_TFM/Raster/Output/Fuel3/AI_Dist_Fuel3.jpg")

# %%
# Distribution of the aggregation Index of Fuel 4 when using MW5

# %%
AIMW5Fuel4 = pd.read_pickle("/home/coca/Maps_TFM/Raster/Output/Fuel4/AIMW5Fuel4.pkl")
AIMW9Fuel4  = pd.read_pickle("/home/coca/Maps_TFM/Raster/Output/Fuel4/AIMW9Fuel4.pkl")
AIMW13Fuel4  = pd.read_pickle("/home/coca/Maps_TFM/Raster/Output/Fuel4/AIMW13Fuel4.pkl")
AIMW17Fuel4  = pd.read_pickle("/home/coca/Maps_TFM/Raster/Output/Fuel4/AIMW17Fuel4.pkl")
AIMW21Fuel4  = pd.read_pickle("/home/coca/Maps_TFM/Raster/Output/Fuel4/AIMW21Fuel4.pkl")
AIMW25Fuel4  = pd.read_pickle("/home/coca/Maps_TFM/Raster/Output/Fuel4/AIMW25Fuel4.pkl")

# %%
fig = plt.figure(figsize=(10,15))
fig.subplots_adjust(hspace = 0.3, wspace=0.3)

ax1 = fig.add_subplot(3, 2, 1)
ax2 = fig.add_subplot(3, 2, 2)
ax3 = fig.add_subplot(3, 2, 3)
ax4 = fig.add_subplot(3, 2, 4)
ax5 = fig.add_subplot(3, 2, 5)
ax6 = fig.add_subplot(3, 2, 6)
 
ax1.hist(AIMW5Fuel4['AI'], bins=[0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue", edgecolor= 'black')
ax2.hist(AIMW9Fuel4['AI'], bins= [0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax3.hist(AIMW13Fuel4['AI'], bins=[0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax4.hist(AIMW17Fuel4['AI'], bins= [0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax5.hist(AIMW21Fuel4['AI'], bins=[0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax6.hist(AIMW25Fuel4['AI'], bins= [0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')

ax1.set_ylim(0, 85000)
ax2.set_ylim(0, 85000)
ax3.set_ylim(0, 85000)
ax4.set_ylim(0, 85000)
ax5.set_ylim(0, 85000)
ax6.set_ylim(0, 85000)

ax1.set_xlabel('Aggregation Index')
ax2.set_xlabel('Aggregation Index')
ax3.set_xlabel('Aggregation Index')
ax4.set_xlabel('Aggregation Index')
ax5.set_xlabel('Aggregation Index')
ax6.set_xlabel('Aggregation Index')

ax1.set_ylabel('Number of cells')
ax2.set_ylabel('Number of cells')
ax3.set_ylabel('Number of cells')
ax4.set_ylabel('Number of cells')
ax5.set_ylabel('Number of cells')
ax6.set_ylabel('Number of cells')

ax1.set_title('AI distribution of Fuel 4 (MW5)')
ax2.set_title('AI distribution of Fuel 4 (MW9)')
ax3.set_title('AI distribution of Fuel 4 (MW13)')
ax4.set_title('AI distribution of Fuel 4 (MW17)')
ax5.set_title('AI distribution of Fuel 4 (MW21)')
ax6.set_title('AI distribution of Fuel 4 (MW25)')

ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()
ax5.grid()
ax6.grid()

#plt.show()

plt.savefig("/home/coca/Maps_TFM/Raster/Output/Fuel4/AI_Dist_Fuel4.jpg")

# %%
# Distribution of the aggregation Index of Fuel 5 when using MW5

# %%
AIMW5Fuel5 = pd.read_pickle("/home/coca/Maps_TFM/Raster/Output/Fuel5/AIMW5Fuel5.pkl")
AIMW9Fuel5  = pd.read_pickle("/home/coca/Maps_TFM/Raster/Output/Fuel5/AIMW9Fuel5.pkl")
AIMW13Fuel5  = pd.read_pickle("/home/coca/Maps_TFM/Raster/Output/Fuel5/AIMW13Fuel5.pkl")
AIMW17Fuel5  = pd.read_pickle("/home/coca/Maps_TFM/Raster/Output/Fuel5/AIMW17Fuel5.pkl")
AIMW21Fuel5  = pd.read_pickle("/home/coca/Maps_TFM/Raster/Output/Fuel5/AIMW21Fuel5.pkl")
AIMW25Fuel5  = pd.read_pickle("/home/coca/Maps_TFM/Raster/Output/Fuel5/AIMW25Fuel5.pkl")

# %%
fig = plt.figure(figsize=(10,15))
fig.subplots_adjust(hspace = 0.3, wspace=0.3)

ax1 = fig.add_subplot(3, 2, 1)
ax2 = fig.add_subplot(3, 2, 2)
ax3 = fig.add_subplot(3, 2, 3)
ax4 = fig.add_subplot(3, 2, 4)
ax5 = fig.add_subplot(3, 2, 5)
ax6 = fig.add_subplot(3, 2, 6)
 
ax1.hist(AIMW5Fuel5['AI'], bins=[0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue", edgecolor= 'black')
ax2.hist(AIMW9Fuel5['AI'], bins= [0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax3.hist(AIMW13Fuel5['AI'], bins=[0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax4.hist(AIMW17Fuel5['AI'], bins= [0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax5.hist(AIMW21Fuel5['AI'], bins=[0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax6.hist(AIMW25Fuel5['AI'], bins= [0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')

ax1.set_ylim(0, 700)
ax2.set_ylim(0, 700)
ax3.set_ylim(0, 700)
ax4.set_ylim(0, 700)
ax5.set_ylim(0, 700)
ax6.set_ylim(0, 700)

ax1.set_xlabel('Aggregation Index')
ax2.set_xlabel('Aggregation Index')
ax3.set_xlabel('Aggregation Index')
ax4.set_xlabel('Aggregation Index')
ax5.set_xlabel('Aggregation Index')
ax6.set_xlabel('Aggregation Index')

ax1.set_ylabel('Number of cells')
ax2.set_ylabel('Number of cells')
ax3.set_ylabel('Number of cells')
ax4.set_ylabel('Number of cells')
ax5.set_ylabel('Number of cells')
ax6.set_ylabel('Number of cells')

ax1.set_title('AI distribution of Fuel 5 (MW5)')
ax2.set_title('AI distribution of Fuel 5 (MW9)')
ax3.set_title('AI distribution of Fuel 5 (MW13)')
ax4.set_title('AI distribution of Fuel 5 (MW17)')
ax5.set_title('AI distribution of Fuel 5 (MW21)')
ax6.set_title('AI distribution of Fuel 5 (MW25)')

ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()
ax5.grid()
ax6.grid()

#plt.show()

plt.savefig("/home/coca/Maps_TFM/Raster/Output/Fuel5/AI_Dist_Fuel5.jpg")

# %%
# Distribution of the aggregation Index of Fuels 1 - 5 when using MW5, MW9, MW13, MW17, MW21 and MW25

# %%
fig = plt.figure(figsize=(25,20))
fig.subplots_adjust(hspace = 0.4, wspace=0.5)

ax1 = fig.add_subplot(5, 6, 1)
ax2 = fig.add_subplot(5, 6, 2)
ax3 = fig.add_subplot(5, 6, 3)
ax4 = fig.add_subplot(5, 6, 4)
ax5 = fig.add_subplot(5, 6, 5)
ax6 = fig.add_subplot(5, 6, 6)
ax7 = fig.add_subplot(5, 6, 7)
ax8 = fig.add_subplot(5, 6, 8)
ax9 = fig.add_subplot(5, 6, 9)
ax10 = fig.add_subplot(5, 6, 10)
ax11 = fig.add_subplot(5, 6, 11)
ax12 = fig.add_subplot(5, 6, 12)
ax13 = fig.add_subplot(5, 6, 13)
ax14 = fig.add_subplot(5, 6, 14)
ax15 = fig.add_subplot(5, 6, 15)
ax16 = fig.add_subplot(5, 6, 16)
ax17 = fig.add_subplot(5, 6, 17)
ax18 = fig.add_subplot(5, 6, 18)
ax19 = fig.add_subplot(5, 6, 19)
ax20 = fig.add_subplot(5, 6, 20)
ax21 = fig.add_subplot(5, 6, 21)
ax22 = fig.add_subplot(5, 6, 22)
ax23 = fig.add_subplot(5, 6, 23)
ax24 = fig.add_subplot(5, 6, 24)
ax25 = fig.add_subplot(5, 6, 25)
ax26 = fig.add_subplot(5, 6, 26)
ax27 = fig.add_subplot(5, 6, 27)
ax28 = fig.add_subplot(5, 6, 28)
ax29 = fig.add_subplot(5, 6, 29)
ax30 = fig.add_subplot(5, 6, 30)
 
ax1.hist(AIMW5Fuel1['AI'], bins=[0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue", edgecolor= 'black')
ax2.hist(AIMW9Fuel1['AI'], bins= [0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax3.hist(AIMW13Fuel1['AI'], bins=[0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax4.hist(AIMW17Fuel1['AI'], bins= [0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax5.hist(AIMW21Fuel1['AI'], bins=[0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax6.hist(AIMW25Fuel1['AI'], bins= [0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax7.hist(AIMW5Fuel2['AI'], bins=[0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue", edgecolor= 'black')
ax8.hist(AIMW9Fuel2['AI'], bins= [0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax9.hist(AIMW13Fuel2['AI'], bins=[0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax10.hist(AIMW17Fuel2['AI'], bins= [0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax11.hist(AIMW21Fuel2['AI'], bins=[0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax12.hist(AIMW25Fuel2['AI'], bins= [0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax13.hist(AIMW5Fuel3['AI'], bins=[0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue", edgecolor= 'black')
ax14.hist(AIMW9Fuel3['AI'], bins= [0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax15.hist(AIMW13Fuel3['AI'], bins=[0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax16.hist(AIMW17Fuel3['AI'], bins= [0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax17.hist(AIMW21Fuel3['AI'], bins=[0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax18.hist(AIMW25Fuel3['AI'], bins= [0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax19.hist(AIMW5Fuel4['AI'], bins=[0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue", edgecolor= 'black')
ax20.hist(AIMW9Fuel4['AI'], bins= [0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax21.hist(AIMW13Fuel4['AI'], bins=[0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax22.hist(AIMW17Fuel4['AI'], bins= [0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax23.hist(AIMW21Fuel4['AI'], bins=[0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax24.hist(AIMW25Fuel4['AI'], bins= [0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax25.hist(AIMW5Fuel5['AI'], bins=[0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue", edgecolor= 'black')
ax26.hist(AIMW9Fuel5['AI'], bins= [0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax27.hist(AIMW13Fuel5['AI'], bins=[0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax28.hist(AIMW17Fuel5['AI'], bins= [0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax29.hist(AIMW21Fuel5['AI'], bins=[0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')
ax30.hist(AIMW25Fuel5['AI'], bins= [0,0.10,0.20,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1], color="cadetblue",edgecolor= 'black')

ax1.set_ylim(0, 600000)
ax2.set_ylim(0, 600000)
ax3.set_ylim(0, 600000)
ax4.set_ylim(0, 600000)
ax5.set_ylim(0, 600000)
ax6.set_ylim(0, 600000)
ax7.set_ylim(0, 6000)
ax8.set_ylim(0, 6000)
ax9.set_ylim(0, 6000)
ax10.set_ylim(0, 6000)
ax11.set_ylim(0, 6000)
ax12.set_ylim(0, 6000)
ax13.set_ylim(0, 800000)
ax14.set_ylim(0, 800000)
ax15.set_ylim(0, 800000)
ax16.set_ylim(0, 800000)
ax17.set_ylim(0, 800000)
ax18.set_ylim(0, 800000)
ax19.set_ylim(0, 85000)
ax20.set_ylim(0, 85000)
ax21.set_ylim(0, 85000)
ax22.set_ylim(0, 85000)
ax23.set_ylim(0, 85000)
ax24.set_ylim(0, 85000)
ax25.set_ylim(0, 700)
ax26.set_ylim(0, 700)
ax27.set_ylim(0, 700)
ax28.set_ylim(0, 700)
ax29.set_ylim(0, 700)
ax30.set_ylim(0, 700)

ax1.set_xlabel('Aggregation Index')
ax2.set_xlabel('Aggregation Index')
ax3.set_xlabel('Aggregation Index')
ax4.set_xlabel('Aggregation Index')
ax5.set_xlabel('Aggregation Index')
ax6.set_xlabel('Aggregation Index')
ax7.set_xlabel('Aggregation Index')
ax8.set_xlabel('Aggregation Index')
ax9.set_xlabel('Aggregation Index')
ax10.set_xlabel('Aggregation Index')
ax11.set_xlabel('Aggregation Index')
ax12.set_xlabel('Aggregation Index')
ax13.set_xlabel('Aggregation Index')
ax14.set_xlabel('Aggregation Index')
ax15.set_xlabel('Aggregation Index')
ax16.set_xlabel('Aggregation Index')
ax17.set_xlabel('Aggregation Index')
ax18.set_xlabel('Aggregation Index')
ax19.set_xlabel('Aggregation Index')
ax20.set_xlabel('Aggregation Index')
ax21.set_xlabel('Aggregation Index')
ax22.set_xlabel('Aggregation Index')
ax23.set_xlabel('Aggregation Index')
ax24.set_xlabel('Aggregation Index')
ax25.set_xlabel('Aggregation Index')
ax26.set_xlabel('Aggregation Index')
ax27.set_xlabel('Aggregation Index')
ax28.set_xlabel('Aggregation Index')
ax29.set_xlabel('Aggregation Index')
ax30.set_xlabel('Aggregation Index')

ax1.set_ylabel('Number of cells')
ax2.set_ylabel('Number of cells')
ax3.set_ylabel('Number of cells')
ax4.set_ylabel('Number of cells')
ax5.set_ylabel('Number of cells')
ax6.set_ylabel('Number of cells')
ax7.set_ylabel('Number of cells')
ax8.set_ylabel('Number of cells')
ax9.set_ylabel('Number of cells')
ax10.set_ylabel('Number of cells')
ax11.set_ylabel('Number of cells')
ax12.set_ylabel('Number of cells')
ax13.set_ylabel('Number of cells')
ax14.set_ylabel('Number of cells')
ax15.set_ylabel('Number of cells')
ax16.set_ylabel('Number of cells')
ax17.set_ylabel('Number of cells')
ax18.set_ylabel('Number of cells')
ax19.set_ylabel('Number of cells')
ax20.set_ylabel('Number of cells')
ax21.set_ylabel('Number of cells')
ax22.set_ylabel('Number of cells')
ax23.set_ylabel('Number of cells')
ax24.set_ylabel('Number of cells')
ax25.set_ylabel('Number of cells')
ax26.set_ylabel('Number of cells')
ax27.set_ylabel('Number of cells')
ax28.set_ylabel('Number of cells')
ax29.set_ylabel('Number of cells')
ax30.set_ylabel('Number of cells')

ax1.set_title('AI distribution of Fuel 1 (MW5)')
ax2.set_title('AI distribution of Fuel 1 (MW9)')
ax3.set_title('AI distribution of Fuel 1 (MW13)')
ax4.set_title('AI distribution of Fuel 1 (MW17)')
ax5.set_title('AI distribution of Fuel 1 (MW21)')
ax6.set_title('AI distribution of Fuel 1 (MW25)')
ax7.set_title('AI distribution of Fuel 2 (MW5)')
ax8.set_title('AI distribution of Fuel 2 (MW9)')
ax9.set_title('AI distribution of Fuel 2 (MW13)')
ax10.set_title('AI distribution of Fuel 2 (MW17)')
ax11.set_title('AI distribution of Fuel 2 (MW21)')
ax12.set_title('AI distribution of Fuel 2 (MW25)')
ax13.set_title('AI distribution of Fuel 3 (MW5)')
ax14.set_title('AI distribution of Fuel 3 (MW9)')
ax15.set_title('AI distribution of Fuel 3 (MW13)')
ax16.set_title('AI distribution of Fuel 3 (MW17)')
ax17.set_title('AI distribution of Fuel 3 (MW21)')
ax18.set_title('AI distribution of Fuel 3 (MW25)')
ax19.set_title('AI distribution of Fuel 4 (MW5)')
ax20.set_title('AI distribution of Fuel 4 (MW9)')
ax21.set_title('AI distribution of Fuel 4 (MW13)')
ax22.set_title('AI distribution of Fuel 4 (MW17)')
ax23.set_title('AI distribution of Fuel 4 (MW21)')
ax24.set_title('AI distribution of Fuel 4 (MW25)')
ax25.set_title('AI distribution of Fuel 5 (MW5)')
ax26.set_title('AI distribution of Fuel 5 (MW9)')
ax27.set_title('AI distribution of Fuel 5 (MW13)')
ax28.set_title('AI distribution of Fuel 5 (MW17)')
ax29.set_title('AI distribution of Fuel 5 (MW21)')
ax30.set_title('AI distribution of Fuel 5 (MW25)')

ax1.grid()
ax2.grid()
ax3.grid()
ax4.grid()
ax5.grid()
ax6.grid()
ax7.grid()
ax8.grid()
ax9.grid()
ax10.grid()
ax11.grid()
ax12.grid()
ax13.grid()
ax14.grid()
ax15.grid()
ax16.grid()
ax17.grid()
ax18.grid()
ax19.grid()
ax20.grid()
ax21.grid()
ax22.grid()
ax23.grid()
ax24.grid()
ax25.grid()
ax26.grid()
ax27.grid()
ax28.grid()
ax29.grid()
ax30.grid()

#plt.show()

plt.savefig("/home/coca/Maps_TFM/Raster/Output/Fuel1/AI_Dist_Fuels1-5.jpg")
